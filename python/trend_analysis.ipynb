# %% [markdown]
# # Trend Analysis
#
# This notebook explores revenue trends and seasonality
# within a retail and logistics dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and Inspect Data

# %%
df = pd.read_csv('data/sample_exports/weekly_revenue.csv')
df.head()
